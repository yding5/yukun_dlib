# %%
import numpy as np
import os
from utils import get_image
import json

# %%
! nvidia-smi
# Out:
# Tue Jan 21 02:37:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.26       Driver Version: 430.26       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  Off  | 00000000:00:07.0 Off |                    0 |
# | N/A   30C    P0    24W / 250W |      0MiB / 16160MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-PCIE...  Off  | 00000000:00:08.0 Off |                    0 |
# | N/A   32C    P0    35W / 250W |  16033MiB / 16160MiB |      0%      Default |
# ...

# %%
from yukun_disentanglement_lib.data.ground_truth import chairs
dta = chairs.Chairs()
# Out:
# finish reading face images
# (100, 64, 64, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(images[58])
plt.show()
